# %%
import pandas as pd
df=pd.read_csv('/content/Wholesale customers data (1).csv',nrows=20)  # nrows is used for how many rows we want to read 
df
# Out:
#     Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0         2       3  12669   9656     7561     214              2674
# 1         2       3   7057   9810     9568    1762              3293
# 2         2       3   6353   8808     7684    2405              3516
# 3         1       3  13265   1196     4221    6404               507
# 4         2       3  22615   5410     7198    3915              1777
# 5         2       3   9413   8259     5126     666              1795
# 6         2       3  12126   3199     6975     480              3140
# 7         2       3   7579   4956     9426    1669              3321
# 8         1       3   5963   3648     6192     425              1716
# 9         2       3   6006  11093    18881    1159              7425
# 10        2       3   3366   5403    12974    4400              5977
# 11        2       3  13146   1124     4523    1420               549
# 12        2       3  31714  12319    11757     287              3881
# ...

# %%
from sklearn.preprocessing import normalize
data_scaled=normalize(df)
data_scaled
# Out:
# array([[1.11821406e-04, 1.67732109e-04, 7.08332695e-01, 5.39873747e-01,
#         4.22740825e-01, 1.19648904e-02, 1.49505220e-01, 7.48085205e-02],
#        [1.25321880e-04, 1.87982820e-04, 4.42198253e-01, 6.14703821e-01,
#         5.99539873e-01, 1.10408576e-01, 2.06342475e-01, 1.11285829e-01],
#        [1.24839188e-04, 1.87258782e-04, 3.96551681e-01, 5.49791784e-01,
#         4.79632161e-01, 1.50119124e-01, 2.19467293e-01, 4.89619296e-01],
#        [6.45937822e-05, 1.93781347e-04, 8.56836521e-01, 7.72541635e-02,
#         2.72650355e-01, 4.13658581e-01, 3.27490476e-02, 1.15493683e-01],
#        [7.91877886e-05, 1.18781683e-04, 8.95415919e-01, 2.14202968e-01,
#         2.84996851e-01, 1.55010096e-01, 7.03583502e-02, 2.05294342e-01],
#        [1.45531533e-04, 2.18297300e-04, 6.84944160e-01, 6.00972466e-01,
#         3.72997319e-01, 4.84620005e-02, 1.30614551e-01, 1.05583127e-01],
#        [1.35984858e-04, 2.03977287e-04, 8.24476195e-01, 2.17507781e-01,
# ...

# %%
#  1.11e-04= 1.11/10000
#  .000111

# %%
data=pd.DataFrame(data_scaled,columns=df.columns)
data
# Out:
#      Channel    Region     Fresh      Milk   Grocery    Frozen  \
# 0   0.000112  0.000168  0.708333  0.539874  0.422741  0.011965
# 1   0.000125  0.000188  0.442198  0.614704  0.599540  0.110409
# 2   0.000125  0.000187  0.396552  0.549792  0.479632  0.150119
# 3   0.000065  0.000194  0.856837  0.077254  0.272650  0.413659
# 4   0.000079  0.000119  0.895416  0.214203  0.284997  0.155010
# 5   0.000146  0.000218  0.684944  0.600972  0.372997  0.048462
# 6   0.000136  0.000204  0.824476  0.217508  0.474247  0.032636
# 7   0.000145  0.000217  0.548036  0.358368  0.681593  0.120685
# 8   0.000105  0.000315  0.625457  0.382637  0.649477  0.044578
# 9   0.000083  0.000125  0.250143  0.462010  0.786371  0.048271
# 10  0.000122  0.000184  0.206006  0.330675  0.794036  0.269289
# 11  0.000142  0.000214  0.936369  0.080061  0.322166  0.101144
# 12  0.000055  0.000083  0.873065  0.339134  0.323662  0.007901
# 13  0.000072  0.000108  0.765560  0.223999  0.540586  0.111675
# ...

# %%
import scipy.cluster.hierarchy as shc      #scipy is scientific python for scientific calculations
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))
plt.title('Dendrogram')
dend=shc.dendrogram(shc.linkage(data_scaled,method='ward'))
